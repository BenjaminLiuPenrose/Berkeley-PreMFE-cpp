# %% [markdown]
# ## Problem 1

# %%
import numpy as np
from numpy.linalg import inv
from numpy import dot

# %%
def capm(y, x, rf):
    # ols reg
    n = y.shape[0]
    ols_y = y - rf
    ols_x = x - rf, ones
    aux = inv( 
        dot(x.T, x)
    ) 
    ols_coeff = dot(
        dot(aux, x.T),
        y
    )
    ols_y_hat = dot(
        x,
        ols_coeff
    )
    alpha = 
    beta =
    
    # r2
    y_mean = np.mean(ols_y)
    tot = np.sum( (ols_y - y_mean) ** 2 )
    reg = np.sum( (ols_y - ols_y_hat) ** 2 )
    res = np.sum( (ols_y_hat - y_mean) ** 2 )
    r_squared = 1 - res / tot
    r_squared_adjusted = 1 - res * (n - 1) / (tot * (n - 1 - 1)) 
    
    # variance-covariance matrix, under homoskedastic
    expected_res_squared = np.mean( (ols_y_hat - ols_y) ** 2 )
    matrix_var_cov = aux * expected_res_squared
    
    # Wald test
    coeff_var = diag(matrix_var_cov)
    coeff_std = np.sqrt(res_var) 
    beta_std =
    alpha_std =
    t_value
    p_value 
    
    # access whether there is signifiant evidence for heterskedastic
    
    # confidence interval
    confidence_interval = {
        "90_percent": (beta - beta_std, beta + beta_std),
        "95_percent": (beta - beta_std, beta + beta_std),
        "99_percent": (beta - beta_std, beta + beta_std)
    }
    
    # variance-covariance matrix under heterskedastic
    matrix_D = diag( (ols_y_hat - ols_y) ** 2 )
    matrix_var_cov_heter = dot(
        dot(
            aux,
            dot(
                dot(x.T, matrix_D),
                x
            )
        ),
        aux
    )
    
    # confidence interval under heterskedastic
    coeff_var_heter
    coeff_std_heter
    beta_std_heter
    alpha_std_heter
    
    confidence_interval_heter = {
        "90_percent":
        "95_percent":
        "99_percent":
    }
    
    # Wald test
    t_value_heter = 
    p_value_heter = 
    
    # AIC, BIC and HQIC
    AIC
    BIC
    HQIC
    
    # DW stat, BG stat
    DW_stat = 
    BG_stat =
    
    
    rtn = {
        "alpha": alpha,
        "beta": beta,
        "coeff": ols_coeff,
        
        "r_squared": r_squared,
        "r_squared_adjusted": r_squared_adjusted,
        
        "matrix_var_cov": matrix_var_cov,
        
        "t_value": t_value,
        
        "confidence_interval": confidence_interval,
        
        "matrix_var_cov_heter": matrix_var_cov_heter,
        
        "confidence_interval_heter": confidence_interval_heter,
        
        "t_value_heter": t_value_heter,
        
        "AIC": AIC,
        "BIC": BIC,
        "HQIC": HQIC,
        
        "DW_stat": DW_stat,
        "BG_stat": BG_stat
    }
